# %%
num1 = 1
print(type(num1))

num2 = 1.0
print(type(num2))

num3 = 3 + 4j
print(type(num3))

print(num1 / num2) # 정수형과 실수형을 연산하면 실수형으로 반환
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# 1.0

# %%
num1 = 11
num2 = 7

print(num1 % num2)
print(num1 // num2)
# Out:
# 4
# 1

# %%
origin = 'ohgiraffers'
with_white_space = '   oh giraffers   '

print(with_white_space)

print(with_white_space.strip())

print(with_white_space.strip('   o'))

print(origin.strip('os'))

print(origin.lstrip('os'))

print(origin.rstrip('os'))
# Out:
#    oh giraffers
# oh giraffers
# h giraffers
# hgiraffer
# hgiraffers
# ohgiraffer

# %%
origin = 'hELLO wORLD!'
print(origin.swapcase())
# Out:
# Hello World!

# %%
a = "a,b,c"
print(a.split(','))
print(",".join(['a', 'b', 'c']))
# Out:
# ['a', 'b', 'c']
# a,b,c

# %%
x = 10
print("x is %d" %x)

y = "code"
print("y is %s" %y)
# Out:
# x is 10
# y is code

# %%
x, y = 10, "code"

print("x is {0}".format(x))                               
print("x is {0} y is {1}".format(x,y))                             
print("x is {new_x} and y is {new_y}".format(new_x=x, new_y=y))
# Out:
# x is 10
# x is 10 y is code
# x is 10 and y is code

# %%
name = "노민환"
print(f"안녕하세요. {name}입니다.")
# Out:
# 안녕하세요. 노민환입니다.

# %%
print(list({
    "1": "사랑하는 우리반",
    "2": "열심히 공부하십시오",
    "3": "-선생님 왈"
}))
# Out:
# ['1', '2', '3']

# %%
age = 27
city = "서울"
print(f"저는 {age}살이고, {city}에 살고 있습니다.")
# Out:
# 저는 27살이고, 서울에 살고 있습니다.
