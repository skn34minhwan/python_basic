# %%
rainbow_split = '빨-주-노-초-파-남-보'
print(rainbow_split.split('-'))
# Out:
# ['빨', '주', '노', '초', '파', '남', '보']

# %%
rain_list = ['빨', '주', '노', '초', '파', '남', '보']
print('|'.join(rain_list))
# Out:
# 빨|주|노|초|파|남|보
