# %%
fruits = set(["apple", "banana", "cherry"])
print(fruits)
# Out:
# {'apple', 'cherry', 'banana'}

# %%
animals = set(["cat", "dog", "bird", "fish"])
animals.remove("bird")
print(animals)
# Out:
# {'dog', 'cat', 'fish'}

# %%
set1 = set([1, 2, 3])
set2 = set([3, 4, 5])
print(set1.union(set2))
# Out:
# {1, 2, 3, 4, 5}

# %%
student = {'name': 'John',
               'age': 20,
               'major':'Computer Science'}
print(student['age'])
# Out:
# 20

# %%
scores ={'math': 80, 'english': 90}
scores['math'] = 95
print(scores)
# Out:
# {'math': 95, 'english': 90}

# %%
colors1 = set(["red", "green", "blue"])
colors2 = set(["blue", "yellow", "pink"])
print(colors1.intersection(colors2))
# Out:
# {'blue'}

# %%
info = dict(name="Alice", age=25, city="Seoul")
print(info.keys())
print(info.values())
# Out:
# dict_keys(['name', 'age', 'city'])
# dict_values(['Alice', 25, 'Seoul'])

# %%
students ={'studetn1': 85, 'student2': 90, 'student3': 95}
students.pop('student2')
print(students)
# Out:
# {'studetn1': 85, 'student3': 95}

# %%
numbers = set([1, 2, 3, 4, 5])
squares = {x**2 for x in numbers}
print(squares)
# Out:
# {1, 4, 9, 16, 25}

# %%
A = set([1, 2, 3, 4])
B = set([3, 4, 5, 6])
print(A.difference(B))
# Out:
# {1, 2}
