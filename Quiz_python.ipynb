# %% [markdown]
# # 🚀 SK 네트웍스 패밀리 AI 캠프: 파이썬 총정리 스터디 퀴즈
# 그동안 배운 파이썬의 핵심 개념들을 총망라한 빈칸 채우기 퀴즈입니다.
# 단순한 암기를 넘어, **파이썬의 핵심 예약어와 흐름**을 이해해야 풀 수 있도록 주요 문법 구문이 모두 빈칸으로 처리되었으며 문제 유형에 대한 힌트도 제거되었습니다. 스터디원들과 함께 빈칸(`___`)을 채우며 실력을 확인해 보세요!
#
# ---
# ### 💡 Part 1: 기본 문법 및 연산자

# %%
# 1.
# 터미널(명령 프롬프트)에서 'myenv'라는 이름의 가상환경을 생성하고 활성화하는 명령어를 완성하세요.
# (터미널 명령어지만 코드 셀에서 빈칸의 정답을 유추해 보세요)
# 생성: python -m ___ myenv
# 활성화: myenv\___\___

# 2.
# 16진수 ff를 할당하고, 지수표현식을 사용해 4.24 * 10^10 을 부동소수점(float)으로 할당하세요.
hex_val = ___
exp_val = ___

# 3.
# 11을 7로 나눈 '몫'과 '나머지'를 구하는 로직을 작성하세요.
quotient = 11 ___ 7
remainder = 11 ___ 7

# 4.
# num이 짝수이면 '짝수', 홀수이면 '홀수'를 반환하는 로직을 한 줄로 작성하세요.
num = 5
result = '짝수' ___ num % 2 == 0 ___ '홀수'
print(result)

# %% [markdown]
# <details>
# <summary><b>👉 Part 1 정답 확인하기</b></summary>
#
# - 1번: `venv`, `Scripts`, `activate`
# - 2번: `0xff`, `4.24e10`
# - 3번: `//`, `%`
# - 4번: `if`, `else`
# </details>
#
# ---
# ### 💡 Part 2: 문자열 다루기

# %%
# 5.
address = '대한민국 서울시 서초구'
# 스텝(Step) 슬라이싱을 활용하여 '서초구'를 역순인 '구초서'로 추출하세요. (인덱스 로직 계산)
reverse_gu = address[___:___:___]

# 6.
# with_white_space의 양쪽 공백을 제거한 뒤, 'a'와 'e'를 이어서 제거하는 체이닝을 완성하세요.
origin = '  apple  '
clean_str = origin.___().___('ae')

# 7.
# origin_str이 'hello'로 시작하는지(True/False) 판별하고, 'WORLD'라는 단어의 시작 인덱스를 찾으세요.
origin_str = 'hello WORLD!'
is_start = origin_str.___(___)
find_idx = origin_str.___(___)

# 8.
# target이 문자와 숫자로만 이루어져 있는지 판별하고, 5자리 중 빈 공간을 '0'으로 채우세요.
target = '42'
is_alnum = target.___()
filled = target.___(___)

# %% [markdown]
# <details>
# <summary><b>👉 Part 2 정답 확인하기</b></summary>
#
# - 5번: `12:9:-1` (인덱스 12('구')부터 10('서')까지 역순 지정)
# - 6번: `strip`, `strip` (또는 `replace` 활용 가능)
# - 7번: `startswith`, `'hello'`, `find`, `'WORLD'`
# - 8번: `isalnum`, `zfill`, `5`
# </details>
#
# ---
# ### 💡 Part 3: 리스트와 자료구조 심화

# %%
# 9, 10.
rainbow = '빨-주-노-초-파-남-보'
rain_list = rainbow.___(___)
rain_str = ___.____(rain_list) # 다시 합치기

# 11, 12, 13.
fruits = ['orange', 'apple', 'banana', 'kiwi']
fruits.___('pineapple')           # 하나의 요소로 덧붙이기
fruits.___(['lemon', 'mango'])    # 리스트를 풀어서 여러 요소로 추가하기
popped = fruits.___()             # 맨 마지막 요소를 빼내며 삭제
fruits.remove('apple')            # 특정 값 삭제
fruits.sort(reverse=___)          # 내림차순으로 원본 정렬

# 14.
tuples = ((1, 2, 'hello'), ('test', 1, 2, 3, 4))
# 'hello'라는 문자열에서 알파벳 'e'만 정확히 추출해 보세요.
val = tuples[___][___][___]

# 15.
# 1부터 10까지의 숫자 중 '홀수의 거듭제곱'만을 요소로 가지는 리스트를 문법 키워드를 활용해 한 줄로 생성하세요.
lst = [n ** 2 ___ n ___ range(1, 11) ___ n % 2 != 0]

# %% [markdown]
# <details>
# <summary><b>👉 Part 3 정답 확인하기</b></summary>
#
# - 9, 10번: `split`, `'-'`, `'-'`, `join` (또는 `''` 공백 조인 가능)
# - 11, 12, 13번: `append`, `extend`, `pop`, `True`
# - 14번: `0`, `2`, `1` (0번째 튜플 -> 2번째 요소('hello') -> 1번째 문자('e'))
# - 15번: `for`, `in`, `if`
# </details>
#
# ---
# ### 💡 Part 4: 세트, 딕셔너리, 그리고 복사

# %%
# 16, 17, 18.
set_a = {'Pig', 'Squirrel', 'Bear'}
set_b = {'Tiger', 'Bear', 'Wolf'}
set_a.___('Elephant')  # 요소 하나 추가
set_a.___('Lion')      # 에러를 발생시키지 않고 안전하게 무시 삭제
sym_diff = set_a ___ set_b # 둘 중 한쪽에만 있는 요소를 구하는 연산자 기호

# 19, 20, 21.
teacher = {'name': 'capybara', 'team': 'ohgiraffers'}
age = teacher.___('age', 'Unknown') # 키가 없을 때 에러 대신 기본값 반환
___ k, v ___ teacher.___():       # 키-값 쌍을 동시에 순회
    pass
last_item = teacher.___()         # 딕셔너리의 마지막 항목을 튜플로 반환하며 삭제

# 22.
import copy
origin = {'name': 'capybara', 'score': [100, 90, 80]}
# 중첩된 리스트 객체까지 완벽하게 독립된 복사본을 생성하세요.
deep = ___.___(___)

# %% [markdown]
# <details>
# <summary><b>👉 Part 4 정답 확인하기</b></summary>
#
# - 16, 17, 18번: `add`, `discard`, `^` (대칭차집합 기호)
# - 19, 20, 21번: `get`, `for`, `in`, `items`, `popitem`
# - 22번: `copy`, `deepcopy`, `origin`
# </details>
#
# ---
# ### 💡 Part 5: 함수 심화와 스코프

# %%
# 23.
customers = ['토끼', '곰', '여우']
# 언패킹과 반복문 문법을 활용해 인덱스와 요소를 동시에 받아오세요.
___ idx, val ___ ___(customers):
    pass

# 24, 25.
d = {'apple': 200, 'dish': 100, 'cook': 500}
# 1. 딕셔너리를 Value(숫자) 기준으로 오름차순 정렬
sorted_by_val = sorted(d.items(), key=___ x: x[1])
# 2. 딕셔너리를 Key(문자) 기준으로 알파벳 역순(내림차순) 정렬
sorted_by_key = sorted(d.items(), key=___ x: x[0], ___=True)

# 26.
g_var = 10
def outer():
    l_var = 20
    def inner():
        ___ g_var # 바깥쪽의 전역 변수 참조 선언
        ___ l_var # 상위 함수의 지역 변수 참조 선언
        g_var = 100
        l_var = 200
    inner()

# %% [markdown]
# <details>
# <summary><b>👉 Part 5 정답 확인하기</b></summary>
#
# - 23번: `for`, `in`, `enumerate`
# - 24, 25번: `lambda`, `lambda`, `reverse`
# - 26번: `global`, `nonlocal`
# </details>
#
# ---
# ### 💡 Part 6: 클래스와 객체지향

# %%
# 27.
class Person:
    def __init__(self, name):
        self.name = name

class Student(___):
    def __init__(self, name, grade):
        # 파이썬 내장 함수를 활용하여 부모 클래스의 초기화 메서드를 실행하세요.
        ___.___(___)
        self.grade = grade

# 28.
class Mentor:
    def __init__(self, field):
        self.field = field

class Lecturer:
    def __init__(self, experience):
        self.experience = experience

class Candidate(___, ___):
    def __init__(self, field, experience):
        # 다중 상속 상황에서 부모 클래스의 이름으로 명시적 초기화를 진행하세요.
        Mentor.___(___, field)
        Lecturer.___(___, experience)

# %% [markdown]
# <details>
# <summary><b>👉 Part 6 정답 확인하기</b></summary>
#
# - 27번: `Person`, `super()`, `__init__`, `name`
# - 28번: `Mentor`, `Lecturer`, `__init__`, `self`, `__init__`, `self`
# </details>
#
# ---
# ### 💡 Part 7: 파일 입출력, 예외처리 및 내장함수

# %%
import csv
import json

# 29.
# 메모리 누수 방지를 위한 컨텍스트 매니저를 활용하여 로그 파일을 읽고, ERROR 키워드를 필터링하세요.
___ open('system.log', 'r', encoding='utf-8') ___ f:
    ___ line ___ f:
        ___ 'ERROR' ___ line:
            print(line)

# 30.
csv_data = [['회사', '결과'], ['A', '합격']]
with open('app.csv', 'w', encoding='utf-8') as f:
    writer = csv.___(f)
    writer.____(csv_data) # 2차원 리스트 한 번에 기록

# 31.
json_data = {'name': '카피바라'}
with open('data.json', 'w', encoding='utf-8') as f:
    # 딕셔너리를 사람이 읽기 좋게 들여쓰기 4칸 옵션을 주어 저장하세요.
    json.___(___, ___, indent=4)

# 32, 33.
___:
    result = 4 / 0
except ZeroDivisionError ___ e:  # 발생한 에러 메시지 자체를 변수에 담기
    print(e)
___:                               # 에러 없이 정상적으로 수행 완료되었을 때 실행
    print('계산 성공')
___:                               # 에러 발생 여부와 무관하게 마지막에 무조건 실행
    print('종료')

# 34, 35.
letters = ['A', 'B', 'C']
numbers = [1, 2, 3]
pair_dict = ___(___(letters, numbers)) # 두 리스트를 묶어 바로 딕셔너리로 변환

pairs = [('A', 1), ('B', 2)]
uz_letters, uz_numbers = ___(___pairs) # 묶인 데이터를 독립된 그룹으로 다시 분리

# %% [markdown]
# <details>
# <summary><b>👉 Part 7 정답 확인하기</b></summary>
#
# - 29번: `with`, `as`, `for`, `in`, `if`, `in`
# - 30번: `writer`, `writerows`
# - 31번: `dump`, `json_data`, `f`
# - 32, 33번: `try`, `as`, `else`, `finally`
# - 34, 35번: `dict`, `zip`, `zip`, `*`
# </details>
