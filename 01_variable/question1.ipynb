# %%
name = "minhwan"
age = 27

print(name, age)
# Out:
# minhwan 27

# %%
height = int(175)
dream = "Ai Engineer"

print(height, dream)
# Out:
# 175 Ai Engineer

# %%
city = "Seoul"
my_city = city
print(city, my_city)
# Out:
# Seoul Seoul

# %%
apple_count = 10
orange_count = 20
print(apple_count, orange_count)
# Out:
# 10 20

# %%
first_name = str("Noh")
last_name = str("Minhwan")
full_name = first_name + " " + last_name
print(full_name)
# Out:
# Noh Minhwan
